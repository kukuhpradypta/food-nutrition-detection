# %% [markdown]
# # Food Nutrition Model - Training di Google Colab
#
# **Langkah pakai:**
# 1. Upload seluruh project (folder ber-zip) ke Google Drive, ATAU upload `image_resource/` + `data/` + file `.py`.
# 2. Pastikan Runtime > Change runtime type > **GPU (T4)**.
# 3. Jalankan cell berurutan dari atas.
# 4. Setelah selesai, download `checkpoints/best_model.pth`.

# %% [markdown]
# ## 1. Cek GPU

# %%
# !nvidia-smi

# %% [markdown]
# ## 2. Clone repository dari GitHub
# Ganti URL dengan repo kamu. Kalau repo private, lihat catatan di bawah.

# %%
import os

REPO_URL = 'https://github.com/kukuhpradypta/food-nutrition-detection.git'  # sesuaikan

# !git clone $REPO_URL /content/project

# Cari folder yang berisi data_training.py
PROJECT_DIR = '/content/project'
for root, dirs, files in os.walk('/content/project'):
    if 'data_training.py' in files:
        PROJECT_DIR = root
        break
os.chdir(PROJECT_DIR)
print('Project dir:', PROJECT_DIR)
print('Files:', os.listdir('.'))
print('Jumlah gambar:', len(os.listdir('image_resource')) if os.path.isdir('image_resource') else 'image_resource TIDAK ADA')

# %% [markdown]
# **Repo private?** Pakai Personal Access Token:
# ```
# REPO_URL = 'https://USERNAME:TOKEN@github.com/kukuhpradypta/food-nutrition-detection.git'
# ```
# Buat token di GitHub > Settings > Developer settings > Personal access tokens (classic), centang scope `repo`.
#
# **Catatan dataset besar:** kalau `image_resource/` di-push via Git LFS, jalankan dulu `!git lfs install && git lfs pull` setelah clone.

# %% [markdown]
# ## 4. Install dependencies (PyTorch sudah ada di Colab)

# %%
# !pip install pandas pillow scikit-learn --quiet

# %% [markdown]
# ## 5. (Opsional) Naikkan batch size & workers untuk GPU
# Edit CONFIG di data_training.py kalau mau lebih cepat. Default sudah aman.

# %% [markdown]
# ## 6. Jalankan Training

# %%
# !python data_training.py

# %% [markdown]
# ## 7. Download hasil model
# Checkpoint tersimpan di `checkpoints/best_model.pth`.

# %%
from google.colab import files
files.download('checkpoints/best_model.pth')

# %% [markdown]
# ## 8. (Opsional) Test inferensi 1 gambar dari validation set

# %%
# !python inference.py --image image_resource/dish_1557853429.png
